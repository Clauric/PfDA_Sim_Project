# %%
import numpy as np
import pandas as pd
from datetime import date

# %% [markdown]
# df = pd.read_csv(r"C:\Users\markb\OneDrive\Desktop\Data Analytics\Programming for data analytics\hourly_irish_weather.csv")
#
# df_dublin = df[df.station == "Dublin_Airport"]
# df_dublin["date"] = pd.to_datetime(df_dublin["date"])
#
# df_new = df_dublin.drop(columns=["Unnamed: 0"])
# df_dublin = df_new[df_new["date"].dt.year > 2014]
#
# df_dublin.to_csv(r"C:\Users\markb\OneDrive\Desktop\Data Analytics\Programming for data analytics\Dublin_Airport_Hourly_Weather.csv")

# %%
url = "https://raw.githubusercontent.com/Clauric/PfDA_Sim_Project/master/Dublin_Airport_Hourly_Weather.csv"
df_dublin = pd.read_csv(url)
df_dublin = df_dublin.drop(columns=["Unnamed: 0", "longitude", "latitude"])

print(df_dublin.dtypes)
print(df_dublin.describe())
print(df_dublin.mode())

df_dublin_corr = df_dublin.corr()

df_dublin_corr = df_dublin_corr.replace({1.00000: ""})

print(df_dublin_corr)
# Out:
# date        object
# station     object
# county      object
# rain       float64
# temp       float64
# wetb       float64
# dewpt      float64
# vappr      float64
# rhum       float64
# msl        float64
# wdsp       float64
# wddir      float64
# ww         float64
# w          float64
# sun        float64
# vis        float64
# clht       float64
# clamt      float64
# dtype: object
#                rain          temp          wetb         dewpt         vappr  \
# count  26304.000000  26304.000000  26304.000000  26304.000000  26304.000000
# mean       0.085641      9.801087      8.303338      6.644575     10.159288
# std        0.405090      4.914089      4.318017      4.325149      2.962800
# min        0.000000     -7.700000     -7.700000     -7.700000      3.400000
# 25%        0.000000      6.300000      5.100000      3.300000      7.700000
# 50%        0.000000     10.000000      8.700000      7.000000     10.000000
# ...
